# %%
import numpy as np
on_color = np.array([0,0,0,1,1,2])
off_color = np.array([0,0,0,0,0,1])

successes = 0
attempts = 10000
for i in range (attempts):
    s = 0
    for dice in range(4):
        r = np.random.choice(on_color)
        print (r)
        s += r
    print ("sum = " + str(s))
    if (s>=6):
        successes +=1
print(successes/attempts)

successes = 0
for i in range(attempts):
    s = 0
    r = np.random.choice(on_color)
    s+= r
    for dice in range(3):
        r = np.random.choice(off_color)
        s += r
    if (s>=4):
        successes +=1

print(successes/attempts)
# Out:
# 2
# 0
# 0
# 1
# sum = 3
# 0
# 0
# 0
# 0
# sum = 0
# 0
# 1
# 0
# 0
# sum = 1
# 0
# 0
# 0
# 1
# sum = 1
# 1
# 1
# 0
# 1
# sum = 3
# 2
# 0
# 1
# 0
# sum = 3
# 0
# 0
# 0
# 1
# sum = 1
# 0
# 1
# 0
# 2
# sum = 3
# 1
# 0
# 0
# 0
# sum = 1
# 2
# 0
# 1
# 2
# sum = 5
# 2
# 0
# 1
# 1
# sum = 4
# 0
# 0
# 1
# 2
# sum = 3
# 1
# 0
# 1
# 1
# sum = 3
# 1
# 1
# 0
# 0
# sum = 2
# 2
# 2
# 0
# 0
# sum = 4
# 0
# 1
# 0
# 0
# sum = 1
# 1
# 0
# 0
# 0
# sum = 1
# 0
# 0
# 2
# 1
# sum = 3
# 1
# 1
# 0
# 0
# sum = 2
# 0
# 0
# 0
# 0
# sum = 0
# 0
# 0
# 2
# 1
# sum = 3
# 0
# 0
# 1
# 1
# sum = 2
# 2
# 0
# 1
# 2
# sum = 5
# 0
# 0
# 1
# 0
# sum = 1
# 0
# 2
# 0
# 0
# sum = 2
# 0
# 0
# 0
# 0
# sum = 0
# 0
# 0
# 0
# 1
# sum = 1
# 2
# 0
# 0
# 0
# sum = 2
# 1
# 1
# 1
# 1
# sum = 4
# 0
# 1
# 1
# 1
# sum = 3
# 1
# 2
# 1
# 0
# sum = 4
# 0
# 1
# 2
# 1
# sum = 4
# 2
# 1
# 1
# 0
# sum = 4
# 1
# 0
# 0
# 0
# sum = 1
# 0
# 0
# 1
# 0
# sum = 1
# 1
# 0
# 0
# 0
# sum = 1
# 2
# 1
# 2
# 1
# sum = 6
# 0
# 0
# 2
# 1
# sum = 3
# 1
# 0
# 0
# ...
